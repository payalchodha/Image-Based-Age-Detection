# %%
from PIL import Image #importing the python image library for PIL
import os,cv2
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import misc 

import matplotlib.image as mpimg

# %%
# Setting the directory path and loading the data from the train and test files
root_dir = os.path.abspath('.')
data_dir_test = './datasets/misctest'
data_dir = './datasets/misctrain'
train = pd.read_csv(os.path.join(data_dir, 'train.csv'))
test = pd.read_csv(os.path.join(data_dir_test, 'test.csv'))

# %%
train.head()
# Out:
#           ID   Class
# 0    377.jpg  MIDDLE
# 1  17814.jpg   YOUNG
# 2  21283.jpg  MIDDLE
# 3  16496.jpg   YOUNG
# 4   4487.jpg  MIDDLE

# %%
train.Class.value_counts().plot(kind="bar",color='grey');

# %%
# randomly loading the image corresponding to the train ID of image.
i = random.choice(train.index)

img_name = train.ID[i]
img = Image.open((os.path.join(data_dir, 'Train', img_name)))

print(f'Age: {train.Class[i]}')
print(img.format, img.size, img.mode)
# Out:
# Age: MIDDLE
# JPEG (101, 110) RGB

# %%
#displaying the random image
imgplot = plt.imshow(img)
plt.show()

# %%
#Checking for the unbalanced classes
train.Class.value_counts()
# Out:
# MIDDLE    10804
# YOUNG      6706
# OLD        2396
# Name: Class, dtype: int64

# %% [markdown]
# # Summary of this notebook
# In this notebook I randomly explored the images to find the possible challanges I can face in using this database for my image processing.
